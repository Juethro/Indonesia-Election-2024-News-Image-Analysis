# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         os.path.join(dirname, filename)

# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Pip install method (recommended)
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.145 🚀 Python-3.7.12 torch-1.11.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 6096.2/8062.4 GB disk)

# %%
# # Git clone method (for development)
# !git clone https://github.com/ultralytics/ultralytics
# %pip install -qe ultralytics

# %% [markdown]
# ## Copy Dataset to Working Directory

# %%
cp -rf /kaggle/input/* /kaggle/working/

# %%
mkdir /kaggle/working/logo-partai-politik-indonesia-pilpres-2024/result

# %%
cd /kaggle/working/logo-partai-politik-indonesia-pilpres-2024/result
# Out:
# /kaggle/working/logo-partai-politik-indonesia-pilpres-2024/result

# %%
# Train YOLOv8n on COCO128 for 300 epochs
# !yolo task=detect mode=train model=yolov8x.pt data=/kaggle/working/logo-partai-politik-indonesia-pilpres-2024/data.yaml epochs=200 imgsz=640 cache=disk
# Out:
# New https://pypi.org/project/ultralytics/8.3.61 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.145 🚀 Python-3.7.12 torch-1.11.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %%
import shutil

folder_to_zip = 'runs'
zip_filename = 'result'

shutil.make_archive(zip_filename, 'zip', folder_to_zip)
# Out:
# '/kaggle/working/logo-partai-politik-indonesia-pilpres-2024/result/result.zip'
